# %%
install.packages("tm")
# Out:
# package 'tm' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\LENOVO\AppData\Local\Temp\Rtmp8Kr57A\downloaded_packages

# %%
install.packages("textclean")
# Out:
# package 'textclean' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\LENOVO\AppData\Local\Temp\RtmpSueoGG\downloaded_packages

# %%
install.packages("tokenizers")
# Out:
# package 'tokenizers' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\LENOVO\AppData\Local\Temp\RtmpSueoGG\downloaded_packages

# %%
install.packages("dplyr")
# Out:
# also installing the dependencies 'glue', 'cli', 'rlang', 'vctrs'
#   There are binary versions available but the source versions are later:
#       binary source needs_compilation
# glue   1.4.2  1.6.2              TRUE
# cli    2.5.0  3.3.0              TRUE
# rlang 0.4.11  1.0.2              TRUE
# vctrs  0.3.8  0.4.1              TRUE
# dplyr  1.0.6  1.0.9              TRUE
#
#   Binaries will be installed
# package 'glue' successfully unpacked and MD5 sums checked
# package 'cli' successfully unpacked and MD5 sums checked
# package 'rlang' successfully unpacked and MD5 sums checked
# package 'vctrs' successfully unpacked and MD5 sums checked
# package 'dplyr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\LENOVO\AppData\Local\Temp\RtmpSueoGG\downloaded_packages

# %%
install.packages("stopwords")
# Out:
#   There is a binary version available but the source version is later:
#           binary source needs_compilation
# stopwords    2.2    2.3             FALSE
# installing the source package 'stopwords'

# %%
install.packages("parallel")
# Out:
# Warning message:
# "package 'parallel' is not available (for R version 3.6.1)"Warning message:
# "package 'parallel' is a base package, and should not be updated"

# %%
install.packages("katadasaR")
# Out:
# Warning message:
# "package 'katadasaR' is not available (for R version 3.6.1)"

# %%
library(tm) # untuk text mining
library(tokenizers) # untuk tokenize kalimat
library(dplyr) # untuk manipulasi data dalam bahasa R
library(textclean) # untuk normalisasi slang word
library(stopwords) # untuk stopword removal
library(parallel) # untuk mengaktifkan function 'Apply'

# %%
proses_cleaning6 <- readLines("../dataset/proses_cleaning6.csv")

# %%
proses_cleaning6[70]

# %%
kamus_slang <- read.csv("../dictonary/colloquial-indonesian-lexicon.csv", sep=",", header=TRUE)
hasil_normalisasi <- replace_internet_slang(proses_cleaning6, slang=paste0("\\b",
                     kamus_slang$slang, "\\b"),
                     replacement=kamus_slang$formal, ignore.case=TRUE)

# %%
hasil_normalisasi
# Out:
#    [1] "content"
#    [2] "Keren dan sangat mudah lihat pulsa tau kuota"
#    [3] "Mantap"
#    [4] "BismiLLah Baik ..."
#    [5] "\"terima kasih Telkomsel, hari ini gue dapat promo kuota 27 GB. Cuma tuker poin sama pulsa 10 dapat kuota gede banget. mantap cuy.\""
#    [6] "Mantap"
#    [7] "Bagus"
#    [8] "Mantap banyak promo di dalam aplikasinya"
#    [9] "\"Aplikasi terbaik, lancar, kencang, banyak paket murahan, user interface user friendly pokoknya debes lah..... Knapa meminta maaf sih bang...kan saya puas tuh atas pelayanannya\""
#   [10] "bagus"
#   [11] "Cukup baik"
#   [12] "Thank you Telkomsel dapat udian 27gb selamat ulang tahun untuk Telkomsel saya sudah pakai jaringan Telkomsel 4 tahun walaupun harganya naik terus menerus"
#   [13] "dapat diakses dimana pun mantap"
#   [14] "bagus"
#   [15] "Nice"
#   [16] "ok"
#   [17] "Aplikasi bagus sangat bermanfaat untuk digunakan"
#   [18] "sangat baik"
#   [19] "Mohon devlover aplikasi ini cepat selesaikan masalah eror pas masuk di aplikasi nya padahal jaringan bagus dan device hp bagus"
#   [20] "semoga telkomsel selalu jaya dan semakin maju"
#   [21] "wokeehhh. . terus perbanyak paket promonya Agar pelanggan senang dan tidak berpaling ke yang lain"
#   [22] "terbaik"
#   [23] "Kemudahan Penggunaan!Mantab"
#   [24] "ya"
#   [25] "sangat memuaaskan"
#   [26] "Tq Telkomsel Call."
#   [27] "Jitu"
#   [28] "sangat lengkap fiturnya"
#   [29] "Good"
#   [30] "Lebih gambang mengecek kuota"
#   [31] "Ok"
#   [32] "sangat baik dan membantu kami"
#   [33] "Aplikasinya bagus deh bermanfaat"
#   [34] "Memudahkan segalanya"
#   [35] "ok benar"
#   [36] "tetap yang terbaik"
#   [37] "Sangat senang menggunakan mytelkomsel"
#   [38] "Stuck di white screen"
#   [39] "Tg"
#   [40] "\"sangat membantu dalam pembelian Kouta,dan bisa terhubung dengan paylater, Untuk bisnis online ðŸ‘\215ðŸ‘\215ðŸ‘\215\""
#   [41] "bagus banget banyak hadiah"
#   [42] "Buka my Telkomsel Lola banget kadang retri terus..padahal kuota Telkomsel banyak Tolong di perbaiki jaringan nya min"
#   [43] "\"Baru update tapi eror,mintolong dong tampilan beranda yang bagian pulsa sama sisa paket enggak muncul,terus pas mau beli paket pakai pulsa jadi enggak bisa tuilasan \"\"muat ulang\"\" Jawaban; OKE MIN SARANNYA sudah BISA MUACHACIH.\""
#   [44] "Ok sih .... Tingkatkan pelayanan terbaik untuk pelanggan..."
#   [45] "baik lancar"
#   [46] "ðŸ‘\215"
#   [47] "memudahkan dan banyak discon"
#   [48] "okk telkomsel"
#   [49] "apk"
#   [50] "ðŸ\230…ðŸ\230…ðŸ\230…ðŸ\230…ðŸ\230…"
#   [51] "ðŸ‘\215ðŸ\217¾"
#   [52] "banyak promo mnarik"
#   [53] "aku sangat suka dengan aplikasi ini"
#   [54] "Mantap"
#   [55] "\"Kasih bintang 5 dulu biar semangat memaksimalkan kinerja ya mytelkomsel,,, walaupun apk nya sering error,tapi sangat membantu.semoga kedepannya lebih baik.\""
#   [56] "\"Tidak dapat memuat halaman Maaf, terdapat kesalahan sistem\""
#   [57] "good apks"
#   [58] "Mantap"
#   [59] "Sangat bagus"
#   [60] "be ur self and never surender"
#   [61] "mantap"
#   [62] "Nenglak kali Telkomsel ðŸ\230¡"
#   [63] "Bagus"
#   [64] "baik sekali"
#   [65] "Mudah dan simpel"
#   [66] "Semoga bermanfaat"
#   [67] "pengin hp baru hp gua sudah pecah parahðŸ\230”"
#   [68] "puaaaaaas"
#   [69] "keren"
#   [70] "selalu jadi yang terdepan our best friends"
#   [71] "Keren banget"
#   [72] "\"Di jaga bersikap komentar yang baik. Ini hanya aplikasi yang dapat berkembang, kalau lu pada cuman mengoceh dan mengasih keluhan saja enggak bisa mengasih saran yang baik, saran gua lu beli di *363# saja Sono. Jadi lah orang yang ikut serta dalam pengembangan bukan malah menyumpahin be9ok, emosi kok di bawa dalam pengisian paket. enggak lu saja yang ngalamin semua pengguna mungkin ngalamin. enggak paham dengan system' kok ngelunjak ADEHHH.\""
#   [73] "jaringan terbaik sepanjang masa"
#   [74] "Keren habis mah Telkomsel."
#   [75] "Bagus sekali"
#   [76] "respon load lama"
#   [77] "bagus"
#   [78] "good job... tapi kenapa masih ada fitur yang belum bisa kebuka. apakah lagi upgrade system.. trmksh"
#   [79] "\"My TELKOMSEL ku bagus-bagus saja sih, enggak kayak yang komen finesh alay banget\""
#   [80] "Aplikasi sngat bagus"
#   [81] "untuk keren"
#   [82] "ðŸ‘\215"
#   [83] "membantu banget apk dan bagus sngat lengkap . hadiah ya juga banyak"
#   [84] "semoga dapat undian"
# ...
# [4973] "1)//1"
# [4974] "bagus"
# [4975] "oke"
# [4976] "menarik"
# [4977] "sangat puas"
# [4978] "good"
# [4979] "\"Apk sangat bagus,dan sangat murah2 juga plsanya\""
# [4980] "apk nya bagus"
# [4981] "mantap"
# [4982] "Sangat membantu"
# [4983] "Siiip"
# [4984] "good"
# [4985] "ok"
# [4986] "\"Aplikasinya bagus,yang jadi permasalahan saya kenapa jaringan Telkomsel sekarang betul-betul jelek,saya pikir harga menentukan kualitas,di antara semua provider di Indonesia mungkin tsel masuk kategori kartu mahal,tapi kenapa mutu jaringan nya sangat jelek,\""
# [4987] "tetap sukses sinyal tambah bagus"
# [4988] "ðŸ‘\215ðŸ‘\215ðŸ‘\215ðŸ‘\215"
# [4989] "Uuhu"
# [4990] "fitur lebih canggih dari sebelumnya lebih user friendly"
# [4991] "top"
# [4992] "makisih"
# [4993] "Sungguh tidak di ragukan sekali apk ini dikarenakan murah banget"
# [4994] "Mantap"
# [4995] "sangat membantu ðŸ\230Š"
# [4996] "ðŸ‘\215ðŸ‘\215ðŸ‘\215ðŸ‘\215"
# [4997] "mantap"
# [4998] "baik"
# [4999] "baik dan mohon untuk lebih banyak promo potongan harga"
# [5000] "sangat membantu"
# [5001] "kotanya murahin dong jangan mahal2"
